# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plot

# %%
df = pd.read_csv("../Data/raw/online_retail_II.csv")

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.shape
# Out:
# (1067371, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_percent.sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 missing_percent = (df.isnull().sum() / len(df)) * 100
#       2
#       3 missing_percent.sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
df = df.dropna(subset=['Customer ID'])

# %%
df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df['Customer ID'] = df['Customer ID'].astype(int)

# %%
df[df['Invoice'].astype(str).str.startswith('C')]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country]
# Index: []

# %%
 df = df[~df['Invoice'].astype(str).str.startswith('C')]

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df = df[df["Quantity"]>0]

# %%
df = df[df["Price"]>0]

# %%
df["Revenue"] = df["Quantity"] * df["Price"]

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Revenue
# ...

# %%
plot.figure(figsize=(10,5))
plot.boxplot(df['Quantity'])
plot.title("Quantity Boxplot")
plot.show()

# %%
plot.figure(figsize=(10,5))
plot.boxplot(df['Revenue'])
plot.title("Revenue Boxplot")
plot.show()

# %%
Q1 = df['Quantity'].quantile(0.25)
Q3 = df['Quantity'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['Quantity'] < lower) | (df['Quantity'] > upper)]

outliers.shape
# Out:
# (51119, 9)

# %%
df['Quantity'] = np.where(
    df['Quantity'] > upper,
    upper,
    df['Quantity']
)

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1        489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2        489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE       27.0
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
# 1067370  581587      POST                              POSTAGE       1.0
#
#                  InvoiceDate  Price  Customer ID         Country  Revenue
# ...

# %%
df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# Revenue        0
# dtype: int64

# %%
df.shape
# Out:
# (779425, 9)

# %%
df.to_csv(
    "../Data/cleaned/cleaned_online_retail.csv"
)

# %% [markdown]
# # After this:
#
# * dataset becomes forecasting-ready
# * customer analytics becomes reliable
# * RFM becomes accurate
# * churn model quality improves
# * dashboard KPIs become trustworthy
