# %%
import joblib

# %%
joblib.dump(

scaler,

"models/saved_models/scaler.pkl"

)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 joblib.dump(
#       2
# ----> 3 scaler,
#       4
#       5 "models/saved_models/scaler.pkl"
#       6
#
# NameError: name 'scaler' is not defined
